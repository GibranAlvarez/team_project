# %%
import sqlite3
import pandas as pd

# Database filename
db_filename = 'Data_Science_Team_Project.db'

try:
    # Connect to the database
    conn = sqlite3.connect(db_filename)

    # Query to retrieve emigrants data
    query_emigrants = "SELECT year, total_emmigrants_per_year FROM total_emmigrants_table WHERE year BETWEEN 1998 AND 2022;"
    emigrants_data = pd.read_sql_query(query_emigrants, conn)

    # Query to retrieve incidents data
    query_incidents = "SELECT year, number FROM incidents WHERE year BETWEEN 1998 AND 2022;"
    incidents_data = pd.read_sql_query(query_incidents, conn)

    # Close connection
    conn.close()
except sqlite3.Error as e:
    print(f"SQLite error: {e}")



# Merge data on 'year' column
combined_data = pd.merge(emigrants_data, incidents_data, on='year', how='inner')
print(combined_data)



# Calculate Pearson correlation coefficient
correlation = combined_data['total_emmigrants_per_year'].corr(combined_data['number'])
print(f"Pearson correlation coefficient: {correlation}")


import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(combined_data['total_emmigrants_per_year'], combined_data['number'], alpha=0.5)
plt.title('Relationship between Emigrants Count and Incidents Count')
plt.xlabel('total_emmigrants_per_year')
plt.ylabel('number of incidents')
plt.grid(True)
plt.show()
# Out:
#     year  total_emmigrants_per_year   number
# 0   1998                      49839  2688540
# 1   1999                      47509  2576445
# 2   2000                      48841  2570663
# 3   2001                      53588  2602571
# 4   2002                      46721  2606967
# 5   2003                      53684  2699428
# 6   2004                      58426  2680221
# 7   2005                      58561  2608741
# 8   2006                      64707  2606887
# 9   2007                      66411  2534730
# 10  2008                      66234  2485043
# 11  2009                      56427  2448654
# 12  2010                      59688  2379130
# 13  2011                      65125  2275917
# 14  2012                      61873  2244458
# 15  2013                      62709  2098776
# 16  2014                      65222  2052925
# 17  2015                      68945  2118681
# 18  2016                      97473  2161927
# 19  2017                     104013  2213293
# ...

# %%
import sqlite3
import pandas as pd

# Database filename
db_filename = 'Data_Science_Team_Project.db'

try:
    # Connect to the database
    conn = sqlite3.connect(db_filename)

    # Query to retrieve emigrants data
    query_emigrants = "SELECT year, total_emmigrants_per_year FROM total_emmigrants_table WHERE year BETWEEN 1990 AND 2022;"
    emigrants_data = pd.read_sql_query(query_emigrants, conn)

    # Query to retrieve incidents data
    query_inflation = "SELECT year, average_cpi_per_year FROM inflation_per_year WHERE year BETWEEN 1990 AND 2022;"
    inflation_data = pd.read_sql_query(query_inflation, conn)

    # Close connection
    conn.close()
except sqlite3.Error as e:
    print(f"SQLite error: {e}")

# Merge data on 'year' column
combined_data = pd.merge(emigrants_data, inflation_data, on='year', how='inner')
print(combined_data)

# Calculate Pearson correlation coefficient
correlation = combined_data['total_emmigrants_per_year'].corr(combined_data['average_cpi_per_year'])
print(f"Pearson correlation coefficient: {correlation}")


import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(combined_data['total_emmigrants_per_year'], combined_data['average_cpi_per_year'], alpha=0.5)
plt.title('Relationship between Emigrants Count and Inflation')
plt.xlabel('total_emmigrants_per_year')
plt.ylabel('cpi rate')
plt.grid(True)
plt.show()
# Out:
#     year  total_emmigrants_per_year  average_cpi_per_year
# 0   1990                      39612              3.958333
# 1   1991                      48030              3.333333
# 2   1992                      44567              1.325000
# 3   1993                      46718              1.591667
# 4   1994                      53281              0.958333
# 5   1995                      50085              1.700000
# 6   1996                      47838              1.316667
# 7   1997                      54263              1.483333
# 8   1998                      49839              1.666667
# 9   1999                      47509              1.883333
# 10  2000                      48841              1.758333
# 11  2001                      53588              2.416667
# 12  2002                      46721              2.241667
# 13  2003                      53684              1.958333
# 14  2004                      58426              1.783333
# ...

# %%
import sqlite3
import pandas as pd

# Database filename
db_filename = 'Data_Science_Team_Project.db'

try:
    # Connect to the database
    conn = sqlite3.connect(db_filename)

    # Query to retrieve emigrants data
    query_emigrants = "SELECT year, total_emmigrants_per_year FROM total_emmigrants_table WHERE year BETWEEN 1976 AND 2022;"
    emigrants_data = pd.read_sql_query(query_emigrants, conn)

    # Query to retrieve incidents data
    query_income = "SELECT year, income FROM median_income WHERE year BETWEEN 1976 AND 2022;"
    income_data = pd.read_sql_query(query_income, conn)

    # Close connection
    conn.close()
except sqlite3.Error as e:
    print(f"SQLite error: {e}")

# Merge data on 'year' column
combined_data = pd.merge(emigrants_data, income_data, on='year', how='inner')
print(combined_data)

# Calculate Pearson correlation coefficient
correlation = combined_data['total_emmigrants_per_year'].corr(combined_data['income'])
print(f"Pearson correlation coefficient: {correlation}")


import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(combined_data['total_emmigrants_per_year'], combined_data['income'], alpha=0.5)
plt.title('Relationship between Emigrants Count and Median income')
plt.xlabel('total_emmigrants_per_year')
plt.ylabel('Income')
plt.grid(True)
plt.show()
# Out:
#     year  total_emmigrants_per_year  income
# 0   1976                      64363   40600
# 1   1977                      61409   40500
# 2   1978                      63474   40400
# 3   1979                      54749   39800
# 4   1980                      45225   39500
# 5   1981                      50052   38800
# 6   1982                      59400   36400
# 7   1983                      58571   35200
# 8   1984                      55241   35500
# 9   1985                      54175   36000
# 10  1986                      49099   36900
# 11  1987                      44312   37500
# 12  1988                      38720   38200
# 13  1989                      40708   39300
# 14  1990                      39612   36600
# 15  1991                      48030   35600
# 16  1992                      44567   35300
# 17  1993                      46718   35300
# 18  1994                      53281   35300
# 19  1995                      50085   35300
# ...

# %%
import sqlite3
import pandas as pd

# Database filename
db_filename = 'Data_Science_Team_Project.db'

try:
    # Connect to the database
    conn = sqlite3.connect(db_filename)

    # Query to retrieve emigrants data
    query_emigrants = "SELECT year, total_emmigrants_per_year FROM total_emmigrants_table WHERE year BETWEEN 1976 AND 2022;"
    emigrants_data = pd.read_sql_query(query_emigrants, conn)

    # Query to retrieve incidents data
    query_unemployement = "SELECT year, rate FROM unemployement_over15 WHERE year BETWEEN 1990 AND 2022;"
    unemployement_data = pd.read_sql_query(query_unemployement, conn)

    # Close connection
    conn.close()
except sqlite3.Error as e:
    print(f"SQLite error: {e}")

# Merge data on 'year' column
combined_data = pd.merge(emigrants_data, unemployement_data, on='year', how='inner')
print(combined_data)

# Calculate Pearson correlation coefficient
correlation = combined_data['total_emmigrants_per_year'].corr(combined_data['rate'])
print(f"Pearson correlation coefficient: {correlation}")


import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(combined_data['total_emmigrants_per_year'], combined_data['rate'], alpha=0.5)
plt.title('Relationship between Emigrants Count and Unemployement rate')
plt.xlabel('total_emmigrants_per_year')
plt.ylabel('Unemployement rate')
plt.grid(True)
plt.show()
# Out:
#     year  total_emmigrants_per_year  rate
# 0   1990                      39612   8.1
# 1   1991                      48030  10.3
# 2   1992                      44567  11.2
# 3   1993                      46718  11.4
# 4   1994                      53281  10.4
# 5   1995                      50085   9.5
# 6   1996                      47838   9.6
# 7   1997                      54263   9.1
# 8   1998                      49839   8.3
# 9   1999                      47509   7.6
# 10  2000                      48841   6.8
# 11  2001                      53588   7.2
# 12  2002                      46721   7.7
# 13  2003                      53684   7.6
# 14  2004                      58426   7.2
# 15  2005                      58561   6.8
# 16  2006                      64707   6.3
# 17  2007                      66411   6.1
# 18  2008                      66234   6.2
# 19  2009                      56427   8.4
# 20  2010                      59688   8.1
# ...
